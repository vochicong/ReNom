# %%
import numpy as np
import renom as rm
from sklearn.datasets import fetch_mldata
from sklearn.preprocessing import LabelBinarizer
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
import renom.utility.distributor.distributor as distr
import renom.cuda as cu
import matplotlib.pyplot as plt

# %%
# First, we gather the normal MNIST Data set and set up the data as per usual

mnist = fetch_mldata('MNIST original', data_home='dataset')
X = mnist.data.astype(np.float64)
X /= np.amax(X)
X = X.reshape(-1, 1, 28, 28)
Y = mnist.target
Y = LabelBinarizer().fit_transform(Y).astype(np.float64)

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.1)

# %%
# We construct the model in two variants, one that can uses layer normalization and one that does not
# The one utilizing layer normalization has more units to train, as gain and bias are trainable parameters

class MNist(rm.Model):
    def __init__(self, use_norm = False):
        super(MNist,self).__init__()
        self.l1 = rm.Conv2d(channel=32,filter=5,padding=2)
        self.a1 = rm.Relu()
        self.l2 = rm.MaxPool2d(filter=2,stride=2)
        if use_norm:
            self.l22 = rm.LayerNormalization()
        self.l3 = rm.Conv2d(channel=64,filter=5,padding=2)
        self.l4 = rm.MaxPool2d(filter=2,stride=2)
        self.l5 = rm.Dense(1024)
        self._norm = use_norm
        self.l6 = rm.Dense(10)

    def forward(self, x):
        ret = self.l1(x)
        ret = self.l2(ret)
        ret = self.a1(ret)
        if self._norm:
            ret = self.l22(ret)
        ret = self.l3(ret)
        ret = self.l4(ret)
        ret = self.a1(ret)
        ret = ret.reshape(ret.shape[0],-1)
        ret = self.l5(ret)
        ret = self.a1(ret)
        ret = self.l6(ret)
        return ret

# %%
# Set up hyperparameters

cu.set_cuda_active(True)
epochs = 40
opt = rm.Sgd(0.001)
batch_size = 100
train_distributor = distr.NdarrayDistributor(X_train,y_train)
# Since we are training one relatively large datasets, we construct another distributor for the test data,
# in order to avoid using too much memory and doing the test in batches.
test_distributor = distr.NdarrayDistributor(X_test,y_test)
normed_model = MNist(use_norm = True)
regular_model = MNist(use_norm = False)
batches = X_train.shape[0]

# %%
# Here we perform the training. For each epoch we first train the normalized model once and then the regular model.
def train_model(distributor, model, train = True):
    loss = 0
    for batch_x, batch_y in distributor.batch(batch_size):
        if train:
            with model.train():
                z = model(batch_x)
                l = rm.softmax_cross_entropy(z,batch_y)
            l.grad().update(opt)
        else:
            z = model(batch_x)
            l = rm.softmax_cross_entropy(z,batch_y)
        loss += l.as_ndarray()
    return loss/(len(distributor)//batch_size+1)
    

normed_loss = []
normed_test = []
regular_loss = []
regular_test = []

for e in range(epochs):
    normed_loss.append(train_model(train_distributor, normed_model, train = True))
    regular_loss.append(train_model(train_distributor, regular_model, train = True))
    print('Finished epoch #{:d} with normalized loss: {} and regular loss: {}'.format(e+1,normed_loss[-1],regular_loss[-1]))
    normed_test.append(train_model(test_distributor, normed_model, train = False))
    regular_test.append(train_model(test_distributor, regular_model, train = False))
    print('Normalized test loss of {} and regular test loss of {}'.format(normed_test[-1], regular_test[-1]))
# Out:
# Finished epoch #1 with normalized loss: [2.0689507] and regular loss: [2.2152472]
# Normalized test loss of [1.7617888] and regular test loss of [2.031241]
# Finished epoch #2 with normalized loss: [1.3467478] and regular loss: [1.3515643]
# Normalized test loss of [0.96899015] and regular test loss of [0.70121676]
# Finished epoch #3 with normalized loss: [0.7336107] and regular loss: [0.5041213]
# Normalized test loss of [0.59468687] and regular test loss of [0.42198437]
# Finished epoch #4 with normalized loss: [0.5072727] and regular loss: [0.35961178]
# Normalized test loss of [0.44950163] and regular test loss of [0.34388423]
# Finished epoch #5 with normalized loss: [0.4069981] and regular loss: [0.30225235]
# Normalized test loss of [0.3877784] and regular test loss of [0.29898614]
# Finished epoch #6 with normalized loss: [0.34914112] and regular loss: [0.2668628]
# Normalized test loss of [0.3379719] and regular test loss of [0.2599951]
# Finished epoch #7 with normalized loss: [0.310143] and regular loss: [0.24085456]
# Normalized test loss of [0.30763832] and regular test loss of [0.23871723]
# Finished epoch #8 with normalized loss: [0.2794307] and regular loss: [0.21977618]
# Normalized test loss of [0.2686292] and regular test loss of [0.22077546]
# Finished epoch #9 with normalized loss: [0.25449005] and regular loss: [0.20296659]
# Normalized test loss of [0.2524548] and regular test loss of [0.20183584]
# Finished epoch #10 with normalized loss: [0.23438358] and regular loss: [0.18802026]
# Normalized test loss of [0.22879842] and regular test loss of [0.18968879]
# Finished epoch #11 with normalized loss: [0.21739617] and regular loss: [0.17551392]
# Normalized test loss of [0.22096077] and regular test loss of [0.17390037]
# Finished epoch #12 with normalized loss: [0.20202036] and regular loss: [0.16383079]
# Normalized test loss of [0.20012325] and regular test loss of [0.16300258]
# Finished epoch #13 with normalized loss: [0.18983167] and regular loss: [0.15393071]
# Normalized test loss of [0.19242106] and regular test loss of [0.15434644]
# Finished epoch #14 with normalized loss: [0.17836419] and regular loss: [0.14504202]
# Normalized test loss of [0.17730908] and regular test loss of [0.14452462]
# Finished epoch #15 with normalized loss: [0.16908135] and regular loss: [0.13731639]
# Normalized test loss of [0.17485487] and regular test loss of [0.14019053]
# Finished epoch #16 with normalized loss: [0.16066149] and regular loss: [0.13037533]
# Normalized test loss of [0.1635133] and regular test loss of [0.1296625]
# Finished epoch #17 with normalized loss: [0.15329751] and regular loss: [0.12375012]
# Normalized test loss of [0.15250619] and regular test loss of [0.12234888]
# Finished epoch #18 with normalized loss: [0.14677055] and regular loss: [0.11796877]
# Normalized test loss of [0.15096264] and regular test loss of [0.11810242]
# Finished epoch #19 with normalized loss: [0.14102973] and regular loss: [0.11288607]
# Normalized test loss of [0.14481851] and regular test loss of [0.1121079]
# Finished epoch #20 with normalized loss: [0.13555053] and regular loss: [0.10836897]
# Normalized test loss of [0.13728091] and regular test loss of [0.10811528]
# Finished epoch #21 with normalized loss: [0.13036543] and regular loss: [0.10384443]
# Normalized test loss of [0.13986842] and regular test loss of [0.1048993]
# Finished epoch #22 with normalized loss: [0.12613091] and regular loss: [0.10011947]
# Normalized test loss of [0.13011603] and regular test loss of [0.10025551]
# Finished epoch #23 with normalized loss: [0.12222558] and regular loss: [0.09629632]
# Normalized test loss of [0.12541942] and regular test loss of [0.09837891]
# Finished epoch #24 with normalized loss: [0.1181761] and regular loss: [0.09302938]
# Normalized test loss of [0.12400326] and regular test loss of [0.09370099]
# Finished epoch #25 with normalized loss: [0.11501132] and regular loss: [0.08995809]
# Normalized test loss of [0.11970831] and regular test loss of [0.09356821]
# Finished epoch #26 with normalized loss: [0.1116332] and regular loss: [0.08710159]
# Normalized test loss of [0.11460111] and regular test loss of [0.08872081]
# Finished epoch #27 with normalized loss: [0.1085421] and regular loss: [0.08457629]
# Normalized test loss of [0.11535096] and regular test loss of [0.08632568]
# Finished epoch #28 with normalized loss: [0.10555312] and regular loss: [0.08203646]
# Normalized test loss of [0.1120994] and regular test loss of [0.08262318]
# Finished epoch #29 with normalized loss: [0.10289028] and regular loss: [0.07988582]
# Normalized test loss of [0.10686023] and regular test loss of [0.08057143]
# Finished epoch #30 with normalized loss: [0.10031305] and regular loss: [0.07735711]
# Normalized test loss of [0.10947442] and regular test loss of [0.08203804]
# Finished epoch #31 with normalized loss: [0.09768993] and regular loss: [0.07541895]
# Normalized test loss of [0.10581615] and regular test loss of [0.07780071]
# Finished epoch #32 with normalized loss: [0.09619872] and regular loss: [0.07335093]
# Normalized test loss of [0.09942518] and regular test loss of [0.07639383]
# Finished epoch #33 with normalized loss: [0.09393123] and regular loss: [0.07171081]
# Normalized test loss of [0.09763974] and regular test loss of [0.07464138]
# Finished epoch #34 with normalized loss: [0.0917598] and regular loss: [0.06991051]
# Normalized test loss of [0.09483732] and regular test loss of [0.07247174]
# Finished epoch #35 with normalized loss: [0.0898353] and regular loss: [0.06852429]
# Normalized test loss of [0.09468191] and regular test loss of [0.07126597]
# Finished epoch #36 with normalized loss: [0.08816694] and regular loss: [0.06676305]
# Normalized test loss of [0.09255034] and regular test loss of [0.06826077]
# Finished epoch #37 with normalized loss: [0.08658839] and regular loss: [0.06537917]
# Normalized test loss of [0.08995557] and regular test loss of [0.06700914]
# Finished epoch #38 with normalized loss: [0.08471701] and regular loss: [0.0637493]
# Normalized test loss of [0.08868741] and regular test loss of [0.06571314]
# Finished epoch #39 with normalized loss: [0.08319881] and regular loss: [0.06268481]
# Normalized test loss of [0.08934929] and regular test loss of [0.06565407]
# Finished epoch #40 with normalized loss: [0.08183841] and regular loss: [0.06118241]
# Normalized test loss of [0.08597791] and regular test loss of [0.0640936]

# %%
# %matplotlib notebook

# Now we plot the data together to show the effect of normalization, nothing too fancy here.

plt.plot(range(epochs),normed_test, label="Normalized")
plt.plot(range(epochs),regular_test, label="Regular")
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
